# %%
import os
import pickle

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from metrics.visualization import visualization

# %matplotlib inline

# %% [markdown]
# ## PCA and t-SNE visualization

# %%
path = "output/FEM100"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 274 samples in 0.000s...
# [t-SNE] Computed neighbors for 274 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 274 / 274
# [t-SNE] Mean sigma: 1.737386
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.688145
# [t-SNE] KL divergence after 300 iterations: 0.080732

# %%
path = "output/FEM_GAN_10"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 274 samples in 0.001s...
# [t-SNE] Computed neighbors for 274 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 274 / 274
# [t-SNE] Mean sigma: 1.505647
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.868752
# [t-SNE] KL divergence after 300 iterations: 0.107497

# %%
path = "output/FEM_GAN_20"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 276 samples in 0.000s...
# [t-SNE] Computed neighbors for 276 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 276 / 276
# [t-SNE] Mean sigma: 1.940490
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.664509
# [t-SNE] KL divergence after 300 iterations: 0.118578

# %%
path = "output/FEM_GAN_30"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 276 samples in 0.000s...
# [t-SNE] Computed neighbors for 276 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 276 / 276
# [t-SNE] Mean sigma: 2.247903
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.735409
# [t-SNE] KL divergence after 300 iterations: 0.116640

# %%
path = "output/FEM_GAN_40"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 276 samples in 0.000s...
# [t-SNE] Computed neighbors for 276 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 276 / 276
# [t-SNE] Mean sigma: 2.429785
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.612762
# [t-SNE] KL divergence after 300 iterations: 0.087946

# %%
path = "output/FEM_GAN_50"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 276 samples in 0.000s...
# [t-SNE] Computed neighbors for 276 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 276 / 276
# [t-SNE] Mean sigma: 2.639675
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.355324
# [t-SNE] KL divergence after 300 iterations: 0.090672

# %%
path = "output/FEM_GAN_60"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 276 samples in 0.000s...
# [t-SNE] Computed neighbors for 276 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 276 / 276
# [t-SNE] Mean sigma: 2.778437
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.956478
# [t-SNE] KL divergence after 300 iterations: 0.103123

# %%
path = "output/FEM_GAN_70"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 276 samples in 0.000s...
# [t-SNE] Computed neighbors for 276 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 276 / 276
# [t-SNE] Mean sigma: 2.816769
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.747314
# [t-SNE] KL divergence after 300 iterations: 0.091090

# %%
path = "output/FEM_GAN_80"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 274 samples in 0.000s...
# [t-SNE] Computed neighbors for 274 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 274 / 274
# [t-SNE] Mean sigma: 3.113425
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.014774
# [t-SNE] KL divergence after 300 iterations: 0.105839

# %%
path = "output/FEM_GAN_90"

with open(f"{path}/train_data.pickle", "rb") as fb:
    ori_data = pickle.load(fb)
    # ori_data = ori_data.reshape(ori_data.shape[0]*ori_data.shape[1], ori_data.shape[2])
with open(f"{path}/fake_data.pickle", "rb") as fb:
    new_data = pickle.load(fb)
    # new_data = new_data.reshape(new_data.shape[0]*new_data.shape[1], new_data.shape[2])
visualization(ori_data, new_data, 'pca')
visualization(ori_data, new_data, 'tsne')
# Out:
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/fneubuerger/.local/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 274 samples in 0.000s...
# [t-SNE] Computed neighbors for 274 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 274 / 274
# [t-SNE] Mean sigma: 2.808007
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.073376
# [t-SNE] KL divergence after 300 iterations: 0.093982
